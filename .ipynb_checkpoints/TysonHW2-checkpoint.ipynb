# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import scipy as sp
from scipy import stats
from pandas import Series
from statsmodels.tsa.stattools import adfuller
from scipy.stats import norm
import statsmodels.api as sm

# %% [markdown]
# __Question 1-1__

# %%
T = 500
phi = 0.25
y = np.zeros(T)
y[0] = np.abs(np.random.normal())
a = np.random.normal(size=T)

for t in range(1,T):
    y[t] = phi * y[t-1] + a[t]
    
y_phi25 = pd.Series(y)
y_phi25.plot(grid=True, color="orange", linewidth=2.5)

# %%
T = 500
phi = 0.5
y = np.zeros(T)
y[0] = np.abs(np.random.normal())
a = np.random.normal(size=T)

for t in range(1,T):
    y[t] = phi * y[t-1] + a[t]
    
y_phi50 = pd.Series(y)
y_phi50.plot(grid=True, color="orange", linewidth=2.5)

# %%
T = 500
phi = 0.75
y = np.zeros(T)
y[0] = np.abs(np.random.normal())
a = np.random.normal(size=T)

for t in range(1,T):
    y[t] = phi * y[t-1] + a[t]
    
y_phi75 = pd.Series(y)
y_phi75.plot(grid=True, color="orange", linewidth=2.5)

# %%
T = 500
phi = 0.8
y = np.zeros(T)
y[0] = np.abs(np.random.normal())
a = np.random.normal(size=T)

for t in range(1,T):
    y[t] = phi * y[t-1] + a[t]
    
y_phi80 = pd.Series(y)
y_phi80.plot(grid=True, color="orange", linewidth=2.5)

# %%
T = 500
phi = 0.9
y = np.zeros(T)
y[0] = np.abs(np.random.normal())
a = np.random.normal(size=T)

for t in range(1,T):
    y[t] = phi * y[t-1] + a[t]
    
y_phi90 = pd.Series(y)
y_phi90.plot(grid=True, color="orange", linewidth=2.5)

# %% [markdown]
# __Question1-3__

# %%
reg_phi25 = sm.OLS(y_phi25.values[1:], y_phi25[0:-1]).fit()

# %%
reg_phi50 = sm.OLS(y_phi50.values[1:], y_phi50[0:-1]).fit()

# %%
reg_phi75 = sm.OLS(y_phi75.values[1:], y_phi75[0:-1]).fit()

# %%
reg_phi80 = sm.OLS(y_phi80.values[1:], y_phi80[0:-1]).fit()

# %%
reg_phi90 = sm.OLS(y_phi90.values[1:], y_phi90[0:-1]).fit()

# %% [markdown]
# __Question1-4__

# %%
sig_01 = norm.ppf((1-(.01/2)))
print(sig_01)
sig_05 = norm.ppf((1-(.05/2)))
print(sig_05)
sig_10 = norm.ppf((1-(.1/2)))
print(sig_10)
# Out:
# 2.5758293035489004
# 1.959963984540054
# 1.6448536269514722

# %%
print(reg_phi25.tvalues)
print(reg_phi25.bse)
print(reg_phi25.pvalues)
# Out:
# x1    5.874684
# dtype: float64
# x1    0.043376
# dtype: float64
# x1    7.756224e-09
# dtype: float64

# %%
print(reg_phi50.tvalues)
print(reg_phi50.bse)
print(reg_phi50.pvalues)
# Out:
# x1    12.704726
# dtype: float64
# x1    0.039077
# dtype: float64
# x1    3.136522e-32
# dtype: float64

# %%
print(reg_phi75.tvalues)
print(reg_phi75.bse)
print(reg_phi75.pvalues)
# Out:
# x1    22.997211
# dtype: float64
# x1    0.031208
# dtype: float64
# x1    2.747578e-80
# dtype: float64

# %%
print(reg_phi80.tvalues)
print(reg_phi80.bse)
print(reg_phi80.pvalues)
# Out:
# x1    28.147004
# dtype: float64
# x1    0.02785
# dtype: float64
# x1    5.134057e-105
# dtype: float64

# %%
print(reg_phi90.tvalues)
print(reg_phi90.bse)
print(reg_phi90.pvalues)
# Out:
# x1    40.236857
# dtype: float64
# x1    0.021782
# dtype: float64
# x1    1.307530e-158
# dtype: float64

# %%
d = {'phi value': [0.25, ' ', ' ', 0.50, ' ', ' ', 0.75, ' ', ' ', 0.80, ' ', ' ', 0.90, ' ', ' '], 'Test Statistic': [reg_phi25.tvalues[0], ' ', ' ', \
reg_phi50.tvalues[0], ' ', ' ', reg_phi75.tvalues[0], ' ', ' ', reg_phi80.tvalues[0], ' ', ' ', reg_phi90.tvalues[0], ' ', ' '], 'Standard Error': \
[reg_phi25.bse[0], ' ', ' ', reg_phi50.bse[0], ' ', ' ', reg_phi75.bse[0], ' ', ' ', reg_phi80.bse[0], ' ', ' ', reg_phi90.bse[0], ' ', ' '], \
'Critical Values': [sig_01, sig_05, sig_10, sig_01, sig_05, sig_10, sig_01, sig_05, sig_10, sig_01, sig_05, sig_10, sig_01, sig_05, sig_10], \
'P-value': [reg_phi25.pvalues[0], ' ', ' ', reg_phi50.pvalues[0], ' ', ' ', reg_phi75.pvalues[0], ' ', ' ', reg_phi80.pvalues[0], ' ', ' ', \
reg_phi90.pvalues[0], ' ', ' '], 'Reject?': ['Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', ]}
df = pd.DataFrame(data=d)
df
# Out:
#    phi value Test Statistic Standard Error  Critical Values       P-value  \
# 0       0.25        5.87468      0.0433761         2.575829   7.75622e-09
# 1                                                  1.959964
# 2                                                  1.644854
# 3        0.5        12.7047      0.0390773         2.575829   3.13652e-32
# 4                                                  1.959964
# 5                                                  1.644854
# 6       0.75        22.9972      0.0312076         2.575829   2.74758e-80
# 7                                                  1.959964
# 8                                                  1.644854
# 9        0.8         28.147      0.0278496         2.575829  5.13406e-105
# 10                                                 1.959964
# 11                                                 1.644854
# 12       0.9        40.2369      0.0217817         2.575829  1.30753e-158
# 13                                                 1.959964
# 14                                                 1.644854
#
#    Reject?
# 0      Yes
# 1      Yes
# 2      Yes
# 3      Yes
# 4      Yes
# 5      Yes
# 6      Yes
# 7      Yes
# 8      Yes
# 9      Yes
# 10     Yes
# 11     Yes
# 12     Yes
# 13     Yes
# 14     Yes

# %% [markdown]
# __Question 1-5__

# %%
CLT_phi8 = np.random.normal(loc = reg_phi80.params[0], scale = reg_phi80.bse[0], size = 100000)

n, bins, patches = plt.hist(x=CLT_phi8, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=1)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Phi = .80')
maxfreq = n.max()

# %%
def SimAR1(phiHat, y0, size):
    y = np.empty(size)
    y[1] = phiHat * y0 + np.random.normal(1)
    u = np.random.normal(size)
  
    for t in range(2, size):
        y[t] = phiHat * y[t-1] + u[t]
    
    return y

# %%
SimAR1(0.8, y[0], T)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-138-cad68ef66d96> in <module>()
# ----> 1 SimAR1(0.8, y[0], T)
#
# <ipython-input-137-e31dbc723dd3> in SimAR1(phiHat, y0, size)
#       5
#       6     for t in range(2, size):
# ----> 7         y[t] = phiHat * y[t-1] + u[t]
#       8
#       9     return y
#
# TypeError: 'float' object is not subscriptable

# %%
reg_phi80 = sm.OLS(y_phi80.values[1:], y_phi80[0:-1]).fit()
# change with monte carlo and bootstrap

# %%
B = 10000

resids = reg_phi80.resid

vals = np.empty(B)

for b in range(B): 
    z = np.random.choice(resids, size=T, replace=True)
    ysim = 0.8 * 1 + z
    res = stats.linregress(0.8, ysim)
    vals[b] = res.slope
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-856dba79c894> in <module>()
#       8     z = np.random.choice(resids, size=T, replace=True)
#       9     ysim = 0.8 * 1 + z
# ---> 10     res = stats.linregress(0.8, ysim)
#      11     vals[b] = res.slope
#
# ~\Anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y)
#      86         raise ValueError("Inputs must not be empty.")
#      87
# ---> 88     n = len(x)
#      89     xmean = np.mean(x, None)
#      90     ymean = np.mean(y, None)
#
# TypeError: len() of unsized object

# %% [markdown]
# __Question 2__

# %%
T = 500
y = np.zeros(T)
y[0] = np.abs(np.random.standard_normal())
x = np.zeros(T)
x[0] = np.abs(np.random.standard_normal())
u1 = np.random.standard_normal(size=T)
u2 = np.random.standard_normal(size=T)

for t in range(1,T):
    y[t] = y[t-1] + u1[t]
    x[t] = x[t-1] + u2[t]
    
y_series = pd.Series(y)
x_series = pd.Series(x)

# %%
x_series = sm.add_constant(x_series)
p2_reg = sm.OLS(y_series.values, x_series.values).fit()

# %%
p2_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     16.23
# Date:                Thu, 28 Feb 2019   Prob (F-statistic):           6.48e-05
# Time:                        12:54:22   Log-Likelihood:                -1877.6
# No. Observations:                 500   AIC:                             3759.
# Df Residuals:                     498   BIC:                             3768.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -11.7359      0.476    -24.671      0.000     -12.671     -10.801
# x1             0.2234      0.055      4.029      0.000       0.114       0.332
# ==============================================================================
# Omnibus:                      420.344   Durbin-Watson:                   0.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.219
# Skew:                          -0.255   Prob(JB):                     8.28e-09
# Kurtosis:                       1.764   Cond. No.                         8.81
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
beta = p2_reg.params[0]
beta
# Out:
# -16.879588831586858

# %%
p2_tstat = p2_reg.tvalues[0]
p2_tstat
# Out:
# -37.0633481894602

# %% [markdown]
# #### We reject the null hypothesis at each significance level.

# %%
n = 50000
z = np.zeros(n)
for i in range(n):
    T = 500
    y = np.zeros(T)
    y[0] = np.abs(np.random.normal())
    x = np.zeros(T)
    x[0] = np.abs(np.random.normal())
    u1 = np.random.normal(size=T)
    u2 = np.random.normal(size=T)

    for t in range(1,T):
        y[t] = y[t-1] + u1[t]
        x[t] = x[t-1] + u2[t]
    
    y_series = pd.Series(y)
    x_series = pd.Series(x)
    
    p2_reg = sm.OLS(y_series.values, x_series).fit()
    beta = p2_reg.params[0]
    
    z[i] = beta

# %%
n, bins, patches = plt.hist(x=z, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=1)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Beta Distribution')
maxfreq = n.max()

# %% [markdown]
# __Problem 3__

# %%
T = 500
phi = 1.0
y = np.zeros(T)
y[0] = np.abs(np.random.normal())
a = np.random.normal(size=T)

for t in range(1,T):
    y[t] = phi * y[t-1] + a[t]
    
y_3 = pd.Series(y)
y_3.plot(grid=True, color="orange", linewidth=2.5)

# %%
reg_y = sm.OLS(y_3.values[1:], y_3[0:-1]).fit()

# %%
d = {'phi value': [1.0, ' ', ' '], 'Test Statistic': [reg_y.tvalues[0], ' ', ' '], 'Standard Error': [reg_y.bse[0], ' ', ' '], \
'Critical Values': [sig_01, sig_05, sig_10], 'P-value': [reg_y.pvalues[0], ' ', ' '], 'Reject?': ['Yes', 'Yes', 'Yes']}
df = pd.DataFrame(data=d)
df
# Out:
#   phi value Test Statistic Standard Error  Critical Values P-value Reject?
# 0         1        253.972     0.00394062         2.575829       0     Yes
# 1                                                 1.959964             Yes
# 2                                                 1.644854             Yes

# %% [markdown]
# __Question 4__

# %%
T = 500
x = np.zeros(T)
x[0] = np.abs(np.random.normal())
u1 = np.random.normal(size=T)
y = np.zeros(T)
y[0] = np.abs(np.random.normal())
alpha = 0.22
beta = 2.50
e = np.random.normal(size=T)

for t in range(1,T):
    x[t] = x[t-1] + u2[t]
    y[t] = alpha + beta * x[t] + e[t]
    
x_series = pd.Series(x)
y_series = pd.Series(y)

# %%
result_x = adfuller(x_series)
print('ADF Statistic: %f' % result_x[0])
print('p-value: %f' % result_x[1])
print('Critical Values:')
for key, value in result_x[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -0.110865
# p-value: 0.948345
# Critical Values:
# 	1%: -3.444
# 	5%: -2.867
# 	10%: -2.570

# %%
result_y = adfuller(y_series)
print('ADF Statistic: %f' % result_y[0])
print('p-value: %f' % result_y[1])
print('Critical Values:')
for key, value in result_y[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -0.362415
# p-value: 0.916188
# Critical Values:
# 	1%: -3.444
# 	5%: -2.867
# 	10%: -2.570
